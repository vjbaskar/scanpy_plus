# %%
import scanpy as sc
import scanpy_plus as scp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import scanpy as sc
# ----> 2 import scanpy_plus as scp
#
# ModuleNotFoundError: No module named 'scanpy_plus'

# %%
# !which python
# Out:
# /Users/vm11/Soft/scanpy_plus/venv/bin/python
