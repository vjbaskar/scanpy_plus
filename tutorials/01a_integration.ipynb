# %%
import scanpy as sc
import scanpy_plus as scp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import scanpy as sc
# ----> 2 import scanpy_plus as scp
#
# File ~/Soft/scanpy_plus/scanpy_plus/__init__.py:10
#       5 from .get_from_raw import * # copies .raw.X to X
#       6 from .is_outlier import * # Outlier
# ---> 10 from . import pl as plot
#      11 from . import io as ios # add notebook to anndata
#      12 from . import tl as tl
#
# File ~/Soft/scanpy_plus/scanpy_plus/pl/__init__.py:14
#      12 from .plotly_umap import * # ridgeplot
#      13 from .umap_allobs import * # umap for all obs
# ---> 14 from .umap3dPlotting import * # 3D UMAP using plotly
#      15 from .umap_grid import * # Plot umap as a grid
#
# File ~/Soft/scanpy_plus/scanpy_plus/pl/umap3dPlotting.py:2
#       1 from ..globimport import *
# ----> 2 import plotly.express as px
# ...

# %%
# !which python
# Out:
# /Users/vm11/Soft/scanpy_plus/venv/bin/python
